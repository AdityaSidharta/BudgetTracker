# %%
# %cd /home/adityasidharta/git/saltedge_python
# Out:
# /home/adityasidharta/git/saltedge_python

# %%
import pandas as pd
import os

import fire
import pandas as pd

from src.utils.directory import RAW_PATH

# %%
pd.options.display.max_rows = 100

# %%
def get_accounts(year, month):
    accounts = []
    for filename in os.listdir(RAW_PATH):
        if filename.endswith("_{}_{}.csv".format(year, month)):
            index = filename.index("_{}_{}.csv".format(year, month))
            account = filename[:index].split(' ')[0]
            accounts.append(account)
    return accounts

# %%
get_accounts(2019, 9)
# Out:
# ['406-02088-6', '421-48697-2', '120-192381-9']

# %%
pd.options.display.max_columns = 200
pd.options.display.max_rows = 200

# %%
year = 2019
month = 9

list_df = []
for filename in os.listdir(RAW_PATH):
    if filename.endswith("_{}_{}.csv".format(year, month)):
        list_df.append(pd.read_csv(os.path.join(RAW_PATH, filename)))
full_df = pd.concat(list_df, axis=0, ignore_index=True)

# %%
full_df = full_df[full_df['duplicated'] == False].copy()

# %%
full_df.groupby('category')['amount'].sum()
# Out:
# category
# auto_and_transport       -170.00
# business_services         100.00
# cafes_and_restaurants     -33.40
# car_rental                -81.19
# entertainment             -38.59
# fees_and_charges          -44.15
# food_and_dining           -10.00
# groceries                 -14.60
# home_supplies             -43.70
# income                   1612.89
# phone                     -78.99
# public_transportation     -41.00
# service_fee                 9.00
# shopping                 -761.65
# taxi                      -37.49
# television                -16.98
# transfer                -6671.22
# transportation            -86.18
# uncategorized             -38.84
# Name: amount, dtype: float64

# %%
full_df[full_df.type == 'AWL']
# Out:
#   index          id account_id duplicated    mode  status     made_on  amount  \
# 7    58  1801236334    9347260      False  normal  posted  2019-09-02  -700.0
#
#   currency_code          description  category type  account_balance_snapshot  \
# 7           SGD  39343836,BRAS BASAH  shopping  AWL                   1058.82
#
#              created_at            updated_at
# 7  2019-10-13T12:19:34Z  2019-10-13T12:19:34Z

# %%
full_df[['id', 'account_id', 'made_on', 'amount', 'description', 'category', 'type']].sort_values('amount', ascending = False)
# Out:
#             id account_id     made_on   amount  \
# 39  1801236518    9347260  2019-09-21   700.00
# 31  1801236486    9347260  2019-09-11   492.29
# 29  1801236478    9347260  2019-09-10   409.96
# 38  1801236514    9347260  2019-09-20   289.35
# 24  1801236458    9347260  2019-09-07   100.00
# 47  1801236550    9347260  2019-09-24    15.80
# 57  1801236762    9347264  2019-09-07    10.59
# 9   1801236342    9347260  2019-09-03    10.06
# 8   1801236338    9347260  2019-09-02     9.00
# 55  1801236582    9347260  2019-09-30     0.03
# 64  1801236790    9347264  2019-09-30     0.02
# 28  1801236474    9347260  2019-09-08    -1.03
# 49  1801236558    9347260  2019-09-25    -1.96
# 3   1801236318    9347260  2019-09-01    -2.51
# 51  1801236566    9347260  2019-09-27    -2.58
# 53  1801236574    9347260  2019-09-28    -2.68
# 54  1801236578    9347260  2019-09-29    -2.68
# 5   1801236326    9347260  2019-09-01    -2.70
# 2   GRAB *DC45B66FBFFD4158 SI NG 30AUG 4628-****-*...     auto_and_transport
# 14  SHOPEE - SINGAPORE SI NG 30AUG 4628-****-****-...               shopping
# 21       CIRCLES.LIFE SI NG 05SEP 4628-****-****-3836                  phone
# 62  UMC-S ERAMAN KLIA SE PA 13SEP 5264-****-****-2...          uncategorized
# 43               IKEA SI NG 21SEP 4628-****-****-3836          home_supplies
# 42  LAZADA SINGAPORE (PAYM SI NG 21SEP 4628-****-*...               shopping
# 30  UBER HELP.UBER.COM 80 05 07SEP 4628-****-****-...                   taxi
# 6   TICKETMASTER COM ME LB 29AUG 4628-****-****-38...          entertainment
# 37  MYREPUBLIC LIMITED SI NG 17SEP 4628-****-****-...                  phone
# 17  GRAB *1373********7021 SI NG 03SEP 4628-4500-3...     auto_and_transport
# 48  GRAB *1373********7021 SI NG 23SEP 4628-4500-3...     auto_and_transport
# 1   GRAB *1373********7021 SI NG 30AUG 4628-4500-3...     auto_and_transport
# 40  SCOOTTFZ9 SI NG 19SEP 4628-****-****-3836 MYR2...         transportation
# 26   KLOOK TECHNOLOGY SI NG 05SEP 4628-****-****-3836             car_rental
# 58                           TRF 406-02088-6 : I-BANK               transfer
# 33      PAYPAL *OSTAY 40 29 11SEP 4628-****-****-3836       fees_and_charges
# 60                           TRF 406-02088-6 : I-BANK               transfer
# 61                           TRF 406-02088-6 : I-BANK               transfer
# 7                                 39343836,BRAS BASAH               shopping
# 52  FAST / PayNow Transfer PayNow Transfer To: Wil...               transfer
# 56       INV DBS Vickers Securities 8082719 014638061               transfer
#
#      type
# 39    CAM
# 31    ITR
# 29    ITR
# 38    MST
# 24    ITR
# 47    MST
# 57    INT
# 9     MST
# 8      SI
# 55    INT
# 64  ATINT
# 28    MST
# 49    MST
# 3     MST
# 51    MST
# 53    MST
# 54    MST
# 5     MST
# 20    MST
# 23    MST
# 41    MST
# 0     MST
# 50    MST
# 46    MST
# 36    MST
# 15    MST
# 18    MST
# 11    MST
# 27    MST
# 16    MST
# 32    MST
# 12    MST
# 34    MST
# 59    POS
# 4     MST
# 63    POS
# 22    MST
# 13    MST
# 19    MST
# 10    MST
# 35    MST
# 44    MST
# 45    MST
# 25    MST
# 2     MST
# 14    MST
# 21    MST
# 62    POS
# 43    MST
# 42    MST
# 30    MST
# 6     MST
# 37    MST
# 17    MST
# 48    MST
# 1     MST
# 40    MST
# 26    MST
# 58    ADV
# 33    MST
# 60    ADV
# 61    ADV
# 7     AWL
# 52    ICT
# 56    ADV

# %%
full_df.type.value_counts()
# Out:
# MST      48
# ADV       4
# POS       3
# ITR       3
# INT       2
# SI        1
# ATINT     1
# AWL       1
# CAM       1
# ICT       1
# Name: type, dtype: int64

# %%
full_df[full_df.type == 'ICT']
# Out:
#    index          id account_id duplicated    mode  status     made_on  \
# 52     3  1801236570    9347260      False  normal  posted  2019-09-28
#
#     amount currency_code                                        description  \
# 52 -783.97           SGD  FAST / PayNow Transfer PayNow Transfer To: Wil...
#
#     category type  account_balance_snapshot            created_at  \
# 52  transfer  ICT                   1058.82  2019-10-13T12:19:36Z
#
#               updated_at
# 52  2019-10-13T12:19:36Z

# %%
import pandas as pd
import glob

path = '/home/adityasidharta/git/saltedge_python/data/raw' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame.type.value_counts()
# Out:
# MST      158
# POS       25
# ITR       24
# ADV       15
# ICT        7
# INT        4
# ATINT      3
# SI         2
# CDM        2
# AWL        2
# CAM        2
# GR         2
# CDF        2
# ATM        1
# D2P        1
# Name: type, dtype: int64

# %%
frame[frame.description.apply(lambda x : 'PAY' in x)]
# Out:
#     index          id account_id duplicated    mode  status     made_on  \
# 9      16  1801236366    9347264      False  normal  posted  2019-08-14
# 14     21  1801236386    9347264      False  normal  posted  2019-08-24
# 15     22  1801236390    9347264      False  normal  posted  2019-08-29
# 51     83  1801236490    9347260      False  normal  posted  2019-09-13
# 52     84  1801236494    9347260      False  normal  posted  2019-09-13
# 53     85  1801236498    9347260      False  normal  posted  2019-09-14
# 54     86  1801236502    9347260      False  normal  posted  2019-09-14
# 55     87  1801236506    9347260      False  normal  posted  2019-09-14
# 57     89  1801236514    9347260      False  normal  posted  2019-09-20
# 61     93  1801236530    9347260      False  normal  posted  2019-09-24
# 88      5  1801235970    9347264      False  normal  posted  2019-07-31
# 140    91  1801236066    9347260      False  normal  posted  2019-08-17
# 155     6  1801236126    9347260      False  normal  posted  2019-08-21
# 174    25  1801236202    9347260      False  normal  posted  2019-08-26
# 195    46  1801236286    9347260      False  normal  posted  2019-08-31
# 222    22  1801235718    9347260      False  normal  posted  2019-07-22
# 234    34  1801235766    9347260      False  normal  posted  2019-07-28
# 235    35  1801235770    9347260      False  normal  posted  2019-07-28
# 240    40  1801235790    9347260      False  normal  posted  2019-07-30
# 245    45  1801235810    9347260      False  normal  posted  2019-07-31
#
#       amount currency_code                                        description  \
# 9     -14.35           SGD  UMC-S LAZADA SINGAPORE (PAYM SI NG 10AUG 5264-...
# 14    -53.39           SGD  UMC-S LAZADA SINGAPORE (PAYM SI NG 21AUG 5264-...
# 15   2974.66           SGD              PAY UCARE.IO PTE. LTD. SALARY PAYMENT
# 51     -6.56           SGD  PAYPAL *OLAAUSTRALI 40 29 11SEP 4628-****-****...
# 52   -304.96           SGD      PAYPAL *OSTAY 40 29 11SEP 4628-****-****-3836
# 53     -7.34           SGD  PAYPAL *OLAAUSTRALI 40 29 12SEP 4628-****-****...
# 54    -11.03           SGD  PAYPAL *OLAAUSTRALI 40 29 12SEP 4628-****-****...
# 55     -3.61           SGD  PAYPAL *OLAAUSTRALI 40 29 12SEP 4628-****-****...
# 57    289.35           SGD      PAYPAL *OSTAY 40 29 18SEP 4628-****-****-3836
# 61    -30.82           SGD  LAZADA SINGAPORE (PAYM SI NG 21SEP 4628-****-*...
