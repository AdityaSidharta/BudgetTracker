# %%
# %cd /home/aditya/git/saltedge_python
# %env PYTHONPATH=/home/aditya/git/saltedge_python
# Out:
# /home/aditya/git/saltedge_python
# env: PYTHONPATH=/home/aditya/git/saltedge_python

# %%
import requests
from src.utils.config import config
from src.saltedge.path import saltedge
from src.saltedge.functions import *

# %%
get_customer_information('ccukii')
# Out:
# ('6899215', 'KHIMR9hjYhupxzdBK3azlkapOxwouXIWlf9ZaYPhMZc')

# %%
# %debug
# Out:
# > /home/aditya/git/saltedge_python/src/saltedge/functions.py(19)get_customer_information()
#      17         content = json.loads(r.content)
#      18         data = content
# ---> 19         customer_id = data['id']
#      20         customer_secret = data['secret']
#      21     return customer_id, customer_secret
#
# ipdb> data
# {'data': {'id': '6899211', 'identifier': 'ccuki', 'secret': 'rz4C3lK0krcr9eFzyMH47ELJrEdVdnJA_rY707lusuw'}}
# ipdb> q

# %%
r = requests.get(saltedgepath.customers_path, headers=config.headers)

# %%
json.loads(r.content)
# Out:
# {'data': [{'id': '4438183',
#    'identifier': 'aditya.sdrt@gmail.com',
#    'secret': 'yi6CZFuP-g7kz2YeffCsV7RtqDkqtcsM1oB5Kl6xF8U'},
#   {'id': '4467964',
#    'identifier': 'default_ff3_customer',
#    'secret': '1y7RcE7TQmzxAKFJPoW0EYgZmMwqy8ZIm1onogh0kDU'},
#   {'id': '4500475',
#    'identifier': 'aditya',
#    'secret': '8jHyQ2vS8rgF2pNyQF4ANXOjSNatMXzgoPwYNpWyXao'},
#   {'id': '4514404',
#    'identifier': 'AdityaSidharta',
#    'secret': 'LnGDsL52W4X0ih8CT3LwmBJJLHP-ihuMmzJKws5SG2M'},
#   {'id': '6899203',
#    'identifier': 'cucu',
#    'secret': '5QsaQB8d4Je7ru8QH3zD4twU9omQ5bLQRrrxhiBt-dA'},
#   {'id': '6899211',
#    'identifier': 'ccuki',
#    'secret': 'rz4C3lK0krcr9eFzyMH47ELJrEdVdnJA_rY707lusuw'},
#   {'id': '6899215',
#    'identifier': 'ccukii',
#    'secret': 'KHIMR9hjYhupxzdBK3azlkapOxwouXIWlf9ZaYPhMZc'}],
#  'meta': {'next_id': None, 'next_page': None}}

# %%
customer_id = '4514404'
r = requests.get(saltedge.connection_path, headers=config.headers, params={'customer_id': customer_id})
content = json.loads(r.content)
validate_content('get_connection', content)
# Out:
# [autoreload of src.saltedge.functions failed: Traceback (most recent call last):
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
# ...

# %%
data = content['data']
# Out:
# [autoreload of src.saltedge.functions failed: Traceback (most recent call last):
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
# ...

# %%
data
# Out:
# [autoreload of src.saltedge.functions failed: Traceback (most recent call last):
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
# ...

# %%
len(content['data'])
# Out:
# [autoreload of src.saltedge.functions failed: Traceback (most recent call last):
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
# ...

# %%
postdata = {"data": {"identifier": 'cucu'}}
r = requests.post(saltedgepath.customers_path, data=json.dumps(postdata))
# Out:
# [autoreload of src.saltedge.path failed: Traceback (most recent call last):
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 450, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 387, in update_generic
#     update(a, b)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 357, in update_class
#     update_instances(old, new)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 312, in update_instances
#     update_instances(old, new, obj.__dict__, visited)
# ...

# %%
json.loads(r.content)
# Out:
# {'data': [{'id': '5489584',
#    'secret': 'T4cJpMRtkv-HqEVJNZMl_cj1Bc_h-VhZknPQbLfLF10',
#    'provider_id': '2271',
#    'provider_code': 'dbs_sg',
#    'provider_name': 'DBS iBanking',
#    'customer_id': '4514404',
#    'next_refresh_possible_at': '2019-07-26T10:51:11Z',
#    'created_at': '2019-07-26T09:38:55Z',
#    'updated_at': '2019-07-26T09:51:11Z',
#    'status': 'active',
#    'categorization': 'personal',
#    'daily_refresh': False,
#    'store_credentials': True,
#    'country_code': 'SG',
#    'last_success_at': '2019-07-26T09:51:11Z',
#    'show_consent_confirmation': True,
#    'last_consent_id': '3617272',
#    'last_attempt': {'id': '278061598',
#     'finished': True,
#     'api_mode': 'service',
#     'api_version': '5',
#     'locale': 'en',
#     'user_present': True,
#     'customer_last_logged_at': None,
#     'remote_ip': '129.126.244.54',
#     'finished_recent': True,
#     'partial': False,
#     'automatic_fetch': False,
#     'daily_refresh': False,
# ...

# %%
config.headers

# %%
json.loads(r.content)
# Out:
# {'data': [{'id': '4438183',
#    'identifier': 'aditya.sdrt@gmail.com',
#    'secret': 'yi6CZFuP-g7kz2YeffCsV7RtqDkqtcsM1oB5Kl6xF8U'},
#   {'id': '4467964',
#    'identifier': 'default_ff3_customer',
#    'secret': '1y7RcE7TQmzxAKFJPoW0EYgZmMwqy8ZIm1onogh0kDU'},
#   {'id': '4500475',
#    'identifier': 'aditya',
#    'secret': '8jHyQ2vS8rgF2pNyQF4ANXOjSNatMXzgoPwYNpWyXao'},
#   {'id': '4514404',
#    'identifier': 'AdityaSidharta',
#    'secret': 'LnGDsL52W4X0ih8CT3LwmBJJLHP-ihuMmzJKws5SG2M'}],
#  'meta': {'next_id': None, 'next_page': None}}

# %%
connect_session('4438183')

# %%
customer = json.loads(r.content)

# %%
customer_identifier = 'AdityaSidharta'
customer_id = [x['id'] for x in customer['data'] if x['identifier'] == customer_identifier][0]
customer_secret = [x['secret'] for x in customer['data'] if x['identifier'] == customer_identifier][0]

# %%
get_customer_information('AdityaSidharta')
# Out:
# ('4514404', 'LnGDsL52W4X0ih8CT3LwmBJJLHP-ihuMmzJKws5SG2M')

# %%
r.co

# %%
# Connect Session
link = 'https://www.saltedge.com/api/v5/connect_sessions/create'

data = {'data' : {
    'customer_id': '4514404',
    'consent': {
        'scopes': ['account_details', 'transactions_details']
    }
}}


r = requests.post(link, headers=config.headers, data=json.dumps(data))

# %%
url_data = json.loads(r.content)

# %%
url_data
# Out:
# {'data': {'expires_at': '2019-10-13T08:37:31Z',
#   'connect_url': 'https://www.saltedge.com/connect?token=87f623f048ba51c8ea47046a3bcf65a7305d47fa76458e6f44c3497f3a1a91f2'}}

# %%
link = 'https://www.saltedge.com/api/v5/connections?customer_id={}'.format('4514404')

r = requests.get(link, headers=config.headers)

# %%
json.loads(r.content)
# Out:
# {'data': [{'id': '5489584',
#    'secret': 'T4cJpMRtkv-HqEVJNZMl_cj1Bc_h-VhZknPQbLfLF10',
#    'provider_id': '2271',
#    'provider_code': 'dbs_sg',
#    'provider_name': 'DBS iBanking',
#    'customer_id': '4514404',
#    'next_refresh_possible_at': '2019-07-26T10:51:11Z',
#    'created_at': '2019-07-26T09:38:55Z',
#    'updated_at': '2019-07-26T09:51:11Z',
#    'status': 'active',
#    'categorization': 'personal',
#    'daily_refresh': False,
#    'store_credentials': True,
#    'country_code': 'SG',
#    'last_success_at': '2019-07-26T09:51:11Z',
#    'show_consent_confirmation': True,
#    'last_consent_id': '3617272',
#    'last_attempt': {'id': '278061598',
#     'finished': True,
#     'api_mode': 'service',
#     'api_version': '5',
#     'locale': 'en',
#     'user_present': True,
#     'customer_last_logged_at': None,
#     'remote_ip': '129.126.244.54',
#     'finished_recent': True,
#     'partial': False,
#     'automatic_fetch': False,
#     'daily_refresh': False,
# ...

# %%
connection_id = json.loads(r.content)['data'][-1]['id']

# %%
connection_id = '5489584'

# %%
link = "https://www.saltedge.com/api/v5/accounts?connection_id={}".format(connection_id)
r = requests.get(link, headers=config.headers)

# %%
json.loads(r.content)['data']
# Out:
# [{'id': '7568825',
#   'connection_id': '5489584',
#   'name': '421-48697-2',
#   'nature': 'savings',
#   'balance': 0.0,
#   'currency_code': 'SGD',
#   'extra': {'cards': ['4628********9304'],
#    'account_name': 'POSB eEveryday Savings Account',
#    'available_amount': 0.0,
#    'transactions_count': {'posted': 2, 'pending': 0},
#    'last_posted_transaction_id': '1373953245'},
#   'created_at': '2019-07-26T09:50:46Z',
#   'updated_at': '2019-07-26T09:50:48Z'},
#  {'id': '7568828',
#   'connection_id': '5489584',
#   'name': '406-02088-6',
#   'nature': 'savings',
#   'balance': 234.66,
#   'currency_code': 'SGD',
#   'extra': {'cards': ['4628********3836', '5548********1927'],
#    'account_name': 'POSB eSavings Account',
#    'available_amount': 221.36,
#    'transactions_count': {'posted': 187, 'pending': 3},
#    'last_posted_transaction_id': '1373953329'},
#   'created_at': '2019-07-26T09:50:46Z',
#   'updated_at': '2019-07-26T09:50:48Z'},
#  {'id': '7568831',
# ...

# %%
account_id = json.loads(r.content)['data']

# %%
connection_id = '5489584'
account_id = '7568825'
# Out:
# [autoreload of src.saltedge.functions failed: Traceback (most recent call last):
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
# ...

# %%
link = "https://www.saltedge.com/api/v5/transactions?connection_id={}&account_id={}".format(connection_id, account_id)
r = requests.get(link, headers=config.headers)

# %%
content = json.loads(r.content)
data = content['data']

# %%
content['meta']
# Out:
# {'next_id': None, 'next_page': None}

# %%
content
# Out:
# {'data': [{'id': '1373952642',
#    'account_id': '7568828',
#    'duplicated': False,
#    'mode': 'normal',
#    'status': 'posted',
#    'made_on': '2019-04-28',
#    'amount': -8.0,
#    'currency_code': 'SGD',
#    'description': 'GRAB *GRABFOOD SI NG 26APR 4628-****-****-3836',
#    'category': 'food_and_dining',
#    'extra': {'type': 'MST',
#     'merchant_id': '05c3d86a459951a50aa674bf38aade075d72e28104e85595948d1f7edc35b2be',
#     'account_balance_snapshot': 234.66,
#     'categorization_confidence': 1},
#    'created_at': '2019-07-26T09:50:46Z',
#    'updated_at': '2019-07-26T09:50:46Z'},
#   {'id': '1373952645',
#    'account_id': '7568828',
#    'duplicated': False,
#    'mode': 'normal',
#    'status': 'posted',
#    'made_on': '2019-04-29',
#    'amount': -33.0,
#    'currency_code': 'SGD',
#    'description': '120-192381-9 : I-BANK',
#    'category': 'business_services',
#    'extra': {'type': 'ITR',
#     'account_balance_snapshot': 234.66,
# ...

# %%
json.loads(r.content)
# Out:
# {'data': [{'id': '1373952642',
#    'account_id': '7568828',
#    'duplicated': False,
#    'mode': 'normal',
#    'status': 'posted',
#    'made_on': '2019-04-28',
#    'amount': -8.0,
#    'currency_code': 'SGD',
#    'description': 'GRAB *GRABFOOD SI NG 26APR 4628-****-****-3836',
#    'category': 'food_and_dining',
#    'extra': {'type': 'MST',
#     'merchant_id': '05c3d86a459951a50aa674bf38aade075d72e28104e85595948d1f7edc35b2be',
#     'account_balance_snapshot': 234.66,
#     'categorization_confidence': 1},
#    'created_at': '2019-07-26T09:50:46Z',
#    'updated_at': '2019-07-26T09:50:46Z'},
#   {'id': '1373952645',
#    'account_id': '7568828',
#    'duplicated': False,
#    'mode': 'normal',
#    'status': 'posted',
#    'made_on': '2019-04-29',
#    'amount': -33.0,
#    'currency_code': 'SGD',
#    'description': '120-192381-9 : I-BANK',
#    'category': 'business_services',
#    'extra': {'type': 'ITR',
#     'account_balance_snapshot': 234.66,
# ...

# %%
pd.DataFrame(json.loads(r.content)['data']).columns
# Out:
# [autoreload of src.saltedge.functions failed: Traceback (most recent call last):
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home/aditya/git/saltedge_python/.venv/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
# ...

# %%
r.status_code
# Out:
# 200
